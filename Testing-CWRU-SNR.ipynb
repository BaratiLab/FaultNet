# %%
# Importing all the required libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from scipy.stats import kurtosis
from scipy.stats import skew

# %%
# Importing the data
data = np.load('CWRU_dataset.npy')
label = np.load('CWRU_lables.npy').reshape(2800,1)

# %%
# Generating white noise
# Calculating the SNR
white_noise_1 = np.clip(np.random.normal(0, 1, data.shape), -0.5, 0.5) # -4.5
signal_energy = np.mean(data**2, axis = 1)
noise_energy = np.mean(white_noise_1**2, axis = 1)
SNR =  10*np.log10(signal_energy/noise_energy)
print(np.mean(SNR), np.max(SNR), np.min(SNR))
###
white_noise_2 = np.clip(np.random.normal(0, 1, data.shape), -0.4, 0.4) # -2.9
signal_energy = np.mean(data**2, axis = 1)
noise_energy = np.mean(white_noise_2**2, axis = 1)
SNR =  10*np.log10(signal_energy/noise_energy)
print(np.mean(SNR), np.max(SNR), np.min(SNR))
###
white_noise_3 = np.clip(np.random.normal(0, 1, data.shape), -0.3, 0.3) # -0.6
signal_energy = np.mean(data**2, axis = 1)
noise_energy = np.mean(white_noise_3**2, axis = 1)
SNR =  10*np.log10(signal_energy/noise_energy)
print(np.mean(SNR), np.max(SNR), np.min(SNR))
###
white_noise_4 = np.clip(np.random.normal(0, 1, data.shape), -0.2, 0.2) # 2.6
signal_energy = np.mean(data**2, axis = 1)
noise_energy = np.mean(white_noise_4**2, axis = 1)
SNR =  10*np.log10(signal_energy/noise_energy)
print(np.mean(SNR), np.max(SNR), np.min(SNR))
###
white_noise_5 = np.clip(np.random.normal(0, 1, data.shape), -0.15, 0.15) # 5
signal_energy = np.mean(data**2, axis = 1)
noise_energy = np.mean(white_noise_5**2, axis = 1)
SNR =  10*np.log10(signal_energy/noise_energy)
print(np.mean(SNR), np.max(SNR), np.min(SNR))
###
white_noise_6 = np.clip(np.random.normal(0, 1, data.shape), -0.1, 0.1) # 8.4
signal_energy = np.mean(data**2, axis = 1)
noise_energy = np.mean(white_noise_6**2, axis = 1)
SNR =  10*np.log10(signal_energy/noise_energy)
print(np.mean(SNR), np.max(SNR), np.min(SNR))
###
white_noise_7 = np.clip(np.random.normal(0, 1, data.shape), -0.075, 0.075) # 10.8
signal_energy = np.mean(data**2, axis = 1)
noise_energy = np.mean(white_noise_7**2, axis = 1)
SNR =  10*np.log10(signal_energy/noise_energy)
print(np.mean(SNR), np.max(SNR), np.min(SNR))
# Out:
# -4.53178939269873 8.912316771674277 -17.347619303686315
# -2.8765261920516005 10.614111083274357 -15.606513853349128
# -0.6501830075600307 12.780734773037395 -13.472719710796694
# 2.6121302086704725 16.05304041915961 -10.249454358025131
# 4.983190366141585 18.452000618669377 -7.825380660794393
# 8.380983795925037 21.814525899787782 -4.45959680283449
# 10.820503024412867 24.263957885115612 -2.022623637711112

# %%
# Noisy data
data1 = data + white_noise_1
data2 = data + white_noise_2
data3 = data + white_noise_3
data4 = data + white_noise_4
data5 = data + white_noise_5
data6 = data + white_noise_6
data7 = data + white_noise_7
del data

# %%
# Saving noisy data
np.save('noisy_data_1.npy',data1)
np.save('noisy_data_2.npy',data2)
np.save('noisy_data_3.npy',data3)
np.save('noisy_data_4.npy',data4)
np.save('noisy_data_5.npy',data5)
np.save('noisy_data_6.npy',data6)
np.save('noisy_data_7.npy',data7)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
def mean(data):
    data = np.asarray(data)
    data.flatten()
    M=data.mean()
    return M
def Max(data):
    data = np.asarray(data)
    data.flatten()
    Max1=data.max()
    return Max1
def Min(data):
    data = np.asarray(data)
    data.flatten()
    Min1=data.min()
    return Min1
def pp(data):
    data = np.asarray(data)
    data.flatten()
    PP=data.max()-data.min()
    return PP
def Variance(data):
    data = np.asarray(data)
    data.flatten()
    Var=data.var()
    return Var
def rms(data):
    data = np.asarray(data)
    data.flatten()
    Rms=np.sqrt(np.mean(data**2))
    return Rms
def Ab_mean(data):
    data = np.asarray(data)
    data.flatten()
    Abm=np.mean(np.absolute(data))
    return Abm
def Shapef(data):
    data = np.asarray(data)
    data.flatten()
    shapef=rms(data)/Ab_mean(data)
    return shapef
def Impulsef(data):
    data = np.asarray(data)
    data.flatten()
    impulse=Max(data)/Ab_mean(data)
    return impulse
def crestf(data):
    data = np.asarray(data)
    data.flatten()
    crest=Max(data)/rms(data)
    return crest
def SQRT_AMPL(data):
    data = np.asarray(data)
    data.flatten()
    SQRTA=(np.mean(np.sqrt(np.absolute(data))))**2
    return SQRTA
def clearancef(data):
    data = np.asarray(data)
    data.flatten()
    clrf=Max(data)/SQRT_AMPL(data)
    return clrf

# %% [markdown]
# Noisy Data 1

# %%
data = data1
feature = []
for i in range(2800):
    feature.append(mean(data[i]))
    feature.append(Max(data[i]))
    feature.append(Min(data[i]))
    feature.append(pp(data[i]))
    feature.append(Variance(data[i]))
    feature.append(rms(data[i]))
    feature.append(Ab_mean(data[i]))
    feature.append(Shapef(data[i]))
    feature.append(Impulsef(data[i]))
    feature.append(crestf(data[i]))
    feature.append(max(abs(data[i])))
    feature.append(clearancef(data[i]))
    K=kurtosis(data[i])
    feature.append(K)
    S=skew(data[i], axis=0, bias=False)
    feature.append(S)
data_f = np.array(feature).reshape(2800,14)
x = data_f
y = label.ravel()
print("Random Forest")
RF=RandomForestClassifier(n_estimators=15,random_state=42)
RF.fit(x,y)
score = cross_val_score(RF, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Support Vector Classifier")
svc=SVC(random_state=100, tol=1e-1)
score = cross_val_score(svc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Logistic Regression")
LR=LogisticRegression(random_state=6, solver='lbfgs',multi_class='multinomial')
score = cross_val_score(LR, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print('K Nearest Neighbors')
knn=KNeighborsClassifier(n_neighbors=75)
score = cross_val_score(knn, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("MLP")
mlpc=MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(512), random_state=10)
score = cross_val_score(mlpc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
# Out:
# Random Forest
# [0.74642857 0.75714286 0.73928571 0.76428571 0.77142857]
# 0.7557142857142857
# **********
# Support Vector Classifier
# [0.62678571 0.60892857 0.60357143 0.61071429 0.62857143]
# 0.6157142857142858
# **********
# Logistic Regression
# [0.65714286 0.65178571 0.66785714 0.68928571 0.69821429]
# 0.6728571428571428
# **********
# K Nearest Neighbors
# [0.67857143 0.66964286 0.65892857 0.6875     0.68928571]
# 0.6767857142857142
# **********
# MLP
# [0.72857143 0.7125     0.71964286 0.72678571 0.7375    ]
# 0.725
# **********

# %% [markdown]
# Noisy Data 2

# %%
data = data2
feature = []
for i in range(2800):
    feature.append(mean(data[i]))
    feature.append(Max(data[i]))
    feature.append(Min(data[i]))
    feature.append(pp(data[i]))
    feature.append(Variance(data[i]))
    feature.append(rms(data[i]))
    feature.append(Ab_mean(data[i]))
    feature.append(Shapef(data[i]))
    feature.append(Impulsef(data[i]))
    feature.append(crestf(data[i]))
    feature.append(max(abs(data[i])))
    feature.append(clearancef(data[i]))
    K=kurtosis(data[i])
    feature.append(K)
    S=skew(data[i], axis=0, bias=False)
    feature.append(S)
data_f = np.array(feature).reshape(2800,14)
x = data_f
y = label.ravel()
print("Random Forest")
RF=RandomForestClassifier(n_estimators=15,random_state=42)
RF.fit(x,y)
score = cross_val_score(RF, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Support Vector Classifier")
svc=SVC(random_state=100, tol=1e-1)
score = cross_val_score(svc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Logistic Regression")
LR=LogisticRegression(random_state=6, solver='lbfgs',multi_class='multinomial')
score = cross_val_score(LR, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print('K Nearest Neighbors')
knn=KNeighborsClassifier(n_neighbors=75)
score = cross_val_score(knn, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("MLP")
mlpc=MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(512), random_state=10)
score = cross_val_score(mlpc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
# Out:
# Random Forest
# [0.78928571 0.75892857 0.77321429 0.78214286 0.7625    ]
# 0.7732142857142857
# **********
# Support Vector Classifier
# [0.64107143 0.63035714 0.60892857 0.625      0.62857143]
# 0.6267857142857143
# **********
# Logistic Regression
# [0.68571429 0.70535714 0.71071429 0.71428571 0.72142857]
# 0.7075000000000001
# **********
# K Nearest Neighbors
# [0.7        0.71428571 0.675      0.68392857 0.66964286]
# 0.6885714285714286
# **********
# MLP
# [0.75535714 0.76607143 0.75       0.74464286 0.75357143]
# 0.7539285714285714
# **********

# %% [markdown]
# Noisy Data 3

# %%
data = data3
feature = []
for i in range(2800):
    feature.append(mean(data[i]))
    feature.append(Max(data[i]))
    feature.append(Min(data[i]))
    feature.append(pp(data[i]))
    feature.append(Variance(data[i]))
    feature.append(rms(data[i]))
    feature.append(Ab_mean(data[i]))
    feature.append(Shapef(data[i]))
    feature.append(Impulsef(data[i]))
    feature.append(crestf(data[i]))
    feature.append(max(abs(data[i])))
    feature.append(clearancef(data[i]))
    K=kurtosis(data[i])
    feature.append(K)
    S=skew(data[i], axis=0, bias=False)
    feature.append(S)
data_f = np.array(feature).reshape(2800,14)
x = data_f
y = label.ravel()
print("Random Forest")
RF=RandomForestClassifier(n_estimators=15,random_state=42)
RF.fit(x,y)
score = cross_val_score(RF, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Support Vector Classifier")
svc=SVC(random_state=100, tol=1e-1)
score = cross_val_score(svc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Logistic Regression")
LR=LogisticRegression(random_state=6, solver='lbfgs',multi_class='multinomial')
score = cross_val_score(LR, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print('K Nearest Neighbors')
knn=KNeighborsClassifier(n_neighbors=75)
score = cross_val_score(knn, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("MLP")
mlpc=MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(512), random_state=10)
score = cross_val_score(mlpc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
# Out:
# Random Forest
# [0.79464286 0.79821429 0.78928571 0.77857143 0.80714286]
# 0.7935714285714285
# **********
# Support Vector Classifier
# [0.64642857 0.63928571 0.61607143 0.64821429 0.63571429]
# 0.6371428571428571
# **********
# Logistic Regression
# [0.70178571 0.71607143 0.72142857 0.71607143 0.73214286]
# 0.7175
# **********
# K Nearest Neighbors
# [0.68214286 0.69107143 0.675      0.69285714 0.68392857]
# 0.685
# **********
# MLP
# [0.76607143 0.74642857 0.74642857 0.75178571 0.78035714]
# 0.7582142857142858
# **********

# %% [markdown]
# Noisy Data 4

# %%
data = data4
feature = []
for i in range(2800):
    feature.append(mean(data[i]))
    feature.append(Max(data[i]))
    feature.append(Min(data[i]))
    feature.append(pp(data[i]))
    feature.append(Variance(data[i]))
    feature.append(rms(data[i]))
    feature.append(Ab_mean(data[i]))
    feature.append(Shapef(data[i]))
    feature.append(Impulsef(data[i]))
    feature.append(crestf(data[i]))
    feature.append(max(abs(data[i])))
    feature.append(clearancef(data[i]))
    K=kurtosis(data[i])
    feature.append(K)
    S=skew(data[i], axis=0, bias=False)
    feature.append(S)
data_f = np.array(feature).reshape(2800,14)
x = data_f
y = label.ravel()
print("Random Forest")
RF=RandomForestClassifier(n_estimators=15,random_state=42)
RF.fit(x,y)
score = cross_val_score(RF, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Support Vector Classifier")
svc=SVC(random_state=100, tol=1e-1)
score = cross_val_score(svc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Logistic Regression")
LR=LogisticRegression(random_state=6, solver='lbfgs',multi_class='multinomial')
score = cross_val_score(LR, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print('K Nearest Neighbors')
knn=KNeighborsClassifier(n_neighbors=75)
score = cross_val_score(knn, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("MLP")
mlpc=MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(512), random_state=10)
score = cross_val_score(mlpc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
# Out:
# Random Forest
# [0.81071429 0.80357143 0.81785714 0.78928571 0.83035714]
# 0.8103571428571428
# **********
# Support Vector Classifier
# [0.675      0.66785714 0.64107143 0.65714286 0.65535714]
# 0.6592857142857144
# **********
# Logistic Regression
# [0.725      0.71785714 0.72142857 0.73928571 0.73214286]
# 0.7271428571428571
# **********
# K Nearest Neighbors
# [0.71071429 0.69464286 0.675      0.70178571 0.69821429]
# 0.6960714285714287
# **********
# MLP
# [0.76964286 0.75714286 0.75892857 0.75357143 0.77678571]
# 0.7632142857142857
# **********

# %% [markdown]
# Noisy Data 5

# %%
data = data5
feature = []
for i in range(2800):
    feature.append(mean(data[i]))
    feature.append(Max(data[i]))
    feature.append(Min(data[i]))
    feature.append(pp(data[i]))
    feature.append(Variance(data[i]))
    feature.append(rms(data[i]))
    feature.append(Ab_mean(data[i]))
    feature.append(Shapef(data[i]))
    feature.append(Impulsef(data[i]))
    feature.append(crestf(data[i]))
    feature.append(max(abs(data[i])))
    feature.append(clearancef(data[i]))
    K=kurtosis(data[i])
    feature.append(K)
    S=skew(data[i], axis=0, bias=False)
    feature.append(S)
data_f = np.array(feature).reshape(2800,14)
x = data_f
y = label.ravel()
print("Random Forest")
RF=RandomForestClassifier(n_estimators=15,random_state=42)
RF.fit(x,y)
score = cross_val_score(RF, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Support Vector Classifier")
svc=SVC(random_state=100, tol=1e-1)
score = cross_val_score(svc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Logistic Regression")
LR=LogisticRegression(random_state=6, solver='lbfgs',multi_class='multinomial')
score = cross_val_score(LR, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print('K Nearest Neighbors')
knn=KNeighborsClassifier(n_neighbors=75)
score = cross_val_score(knn, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("MLP")
mlpc=MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(512), random_state=10)
score = cross_val_score(mlpc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
# Out:
# Random Forest
# [0.82321429 0.82321429 0.82321429 0.81071429 0.84464286]
# 0.825
# **********
# Support Vector Classifier
# [0.68392857 0.675      0.67678571 0.66964286 0.675     ]
# 0.6760714285714287
# **********
# Logistic Regression
# [0.71607143 0.74821429 0.71607143 0.73392857 0.73035714]
# 0.7289285714285714
# **********
# K Nearest Neighbors
# [0.69821429 0.69285714 0.70178571 0.71071429 0.69821429]
# 0.7003571428571428
# **********
# MLP
# [0.76785714 0.77321429 0.76428571 0.76607143 0.78928571]
# 0.7721428571428571
# **********

# %% [markdown]
# Noisy Data 6

# %%
data = data6
feature = []
for i in range(2800):
    feature.append(mean(data[i]))
    feature.append(Max(data[i]))
    feature.append(Min(data[i]))
    feature.append(pp(data[i]))
    feature.append(Variance(data[i]))
    feature.append(rms(data[i]))
    feature.append(Ab_mean(data[i]))
    feature.append(Shapef(data[i]))
    feature.append(Impulsef(data[i]))
    feature.append(crestf(data[i]))
    feature.append(max(abs(data[i])))
    feature.append(clearancef(data[i]))
    K=kurtosis(data[i])
    feature.append(K)
    S=skew(data[i], axis=0, bias=False)
    feature.append(S)
data_f = np.array(feature).reshape(2800,14)
x = data_f
y = label.ravel()
print("Random Forest")
RF=RandomForestClassifier(n_estimators=15,random_state=42)
RF.fit(x,y)
score = cross_val_score(RF, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Support Vector Classifier")
svc=SVC(random_state=100, tol=1e-1)
score = cross_val_score(svc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Logistic Regression")
LR=LogisticRegression(random_state=6, solver='lbfgs',multi_class='multinomial')
score = cross_val_score(LR, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print('K Nearest Neighbors')
knn=KNeighborsClassifier(n_neighbors=75)
score = cross_val_score(knn, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("MLP")
mlpc=MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(512), random_state=10)
score = cross_val_score(mlpc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
# Out:
# Random Forest
# [0.85178571 0.85714286 0.82678571 0.81071429 0.86785714]
# 0.8428571428571429
# **********
# Support Vector Classifier
# [0.69642857 0.69821429 0.66607143 0.69107143 0.7       ]
# 0.6903571428571429
# **********
# Logistic Regression
# [0.7375     0.74464286 0.73035714 0.72857143 0.74642857]
# 0.7375
# **********
# K Nearest Neighbors
# [0.70357143 0.7125     0.7        0.71071429 0.69464286]
# 0.7042857142857144
# **********
# MLP
# [0.78928571 0.78928571 0.75178571 0.74285714 0.79642857]
# 0.7739285714285714
# **********

# %% [markdown]
# Noisy Data 7

# %%
data = data7
feature = []
for i in range(2800):
    feature.append(mean(data[i]))
    feature.append(Max(data[i]))
    feature.append(Min(data[i]))
    feature.append(pp(data[i]))
    feature.append(Variance(data[i]))
    feature.append(rms(data[i]))
    feature.append(Ab_mean(data[i]))
    feature.append(Shapef(data[i]))
    feature.append(Impulsef(data[i]))
    feature.append(crestf(data[i]))
    feature.append(max(abs(data[i])))
    feature.append(clearancef(data[i]))
    K=kurtosis(data[i])
    feature.append(K)
    S=skew(data[i], axis=0, bias=False)
    feature.append(S)
data_f = np.array(feature).reshape(2800,14)
x = data_f
y = label.ravel()
print("Random Forest")
RF=RandomForestClassifier(n_estimators=15,random_state=42)
RF.fit(x,y)
score = cross_val_score(RF, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Support Vector Classifier")
svc=SVC(random_state=100, tol=1e-1)
score = cross_val_score(svc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("Logistic Regression")
LR=LogisticRegression(random_state=6, solver='lbfgs',multi_class='multinomial')
score = cross_val_score(LR, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print('K Nearest Neighbors')
knn=KNeighborsClassifier(n_neighbors=75)
score = cross_val_score(knn, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
print("MLP")
mlpc=MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(512), random_state=10)
score = cross_val_score(mlpc, x, y, cv=5)
print(score)
print(np.mean(np.array(score)))
print('*'*10)
# Out:
# Random Forest
# [0.86964286 0.87321429 0.83035714 0.86785714 0.86607143]
# 0.8614285714285714
# **********
# Support Vector Classifier
# [0.69285714 0.69285714 0.67321429 0.70892857 0.68928571]
# 0.6914285714285715
# **********
# Logistic Regression
# [0.73928571 0.75892857 0.71607143 0.74285714 0.75178571]
# 0.7417857142857143
# **********
# K Nearest Neighbors
# [0.7        0.70178571 0.67142857 0.68928571 0.71071429]
# 0.6946428571428572
# **********
# MLP
# [0.77321429 0.7875     0.75178571 0.75892857 0.78571429]
# 0.7714285714285714
# **********
